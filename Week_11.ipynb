# %% [markdown]
# ### 1. Advanced CRUD Operations
# - **Exercise 1**: Use `bulk_write` to insert, update, and delete multiple documents simultaneously.
# - **Task 1**: Insert a dataset of `courses` where each course has multiple student enrollments, then display the data.

# %%
from pymongo import MongoClient, InsertOne, UpdateOne, DeleteOne

# Establish client connection
client = MongoClient("mongodb://localhost:27017/")
db = client["university_db"]
courses_collection = db["courses"]

# Start with an empty collection
courses_collection.delete_many({})

# Bulk insert of courses with student enrollments
operations = [
    InsertOne({"course": "Math 101", "enrollments": 30, "department": "Mathematics"}),
    InsertOne({"course": "CS 102", "enrollments": 25, "department": "Computer Science"}),
    InsertOne({"course": "History 201", "enrollments": 20, "department": "History"}),
    InsertOne({"course": "Physics 202", "enrollments": 15, "department": "Physics"}),
    InsertOne({"course": "Chemistry 101", "enrollments": 40, "department": "Chemistry"}),
    InsertOne({"course": "Biology 103", "enrollments": 35, "department": "Biology"}),
    InsertOne({"course": "Art History 201", "enrollments": 12, "department": "Art"}),
    InsertOne({"course": "Psychology 102", "enrollments": 50, "department": "Psychology"}),
    InsertOne({"course": "Philosophy 202", "enrollments": 22, "department": "Philosophy"}),
    InsertOne({"course": "Economics 101", "enrollments": 60, "department": "Economics"}),
    InsertOne({"course": "Sociology 101", "enrollments": 45, "department": "Sociology"}),
    InsertOne({"course": "Political Science 102", "enrollments": 30, "department": "Political Science"}),
    InsertOne({"course": "Literature 101", "enrollments": 55, "department": "English"}),
    InsertOne({"course": "Engineering 303", "enrollments": 20, "department": "Engineering"}),
    InsertOne({"course": "Statistics 101", "enrollments": 42, "department": "Mathematics"}),
    InsertOne({"course": "Computer Science 103", "enrollments": 19, "department": "Computer Science"}),
    InsertOne({"course": "Business 101", "enrollments": 80, "department": "Business"}),
    InsertOne({"course": "Marketing 101", "enrollments": 25, "department": "Business"}),
    InsertOne({"course": "Graphic Design 102", "enrollments": 28, "department": "Design"}),
    InsertOne({"course": "Music 201", "enrollments": 18, "department": "Music"}),
    InsertOne({"course": "Dance 101", "enrollments": 30, "department": "Performing Arts"}),
    InsertOne({"course": "Theater 102", "enrollments": 15, "department": "Performing Arts"}),
    InsertOne({"course": "Biochemistry 201", "enrollments": 27, "department": "Biochemistry"}),
    InsertOne({"course": "Engineering 102", "enrollments": 40, "department": "Engineering"}),
    InsertOne({"course": "Astronomy 101", "enrollments": 22, "department": "Physics"}),
    InsertOne({"course": "Geology 101", "enrollments": 16, "department": "Earth Sciences"}),
    InsertOne({"course": "Anthropology 101", "enrollments": 38, "department": "Anthropology"}),
    InsertOne({"course": "Environmental Science 202", "enrollments": 32, "department": "Environmental Studies"}),
    InsertOne({"course": "Public Health 101", "enrollments": 49, "department": "Public Health"}),
    InsertOne({"course": "Urban Planning 101", "enrollments": 21, "department": "Urban Studies"}),
    InsertOne({"course": "Data Science 101", "enrollments": 18, "department": "Computer Science"}),
    InsertOne({"course": "Linguistics 102", "enrollments": 14, "department": "Linguistics"}),
    InsertOne({"course": "Medicine 202", "enrollments": 18, "department": "Medicine"}),
    InsertOne({"course": "Pharmacology 101", "enrollments": 25, "department": "Pharmacy"}),
    InsertOne({"course": "Law 101", "enrollments": 40, "department": "Law"}),
    InsertOne({"course": "Sociology 202", "enrollments": 35, "department": "Sociology"}),
    InsertOne({"course": "Advanced Chemistry 301", "enrollments": 12, "department": "Chemistry"}),
    InsertOne({"course": "Accounting 101", "enrollments": 50, "department": "Accounting"}),
    InsertOne({"course": "Engineering 101", "enrollments": 55, "department": "Engineering"}),
    InsertOne({"course": "Finance 202", "enrollments": 27, "department": "Business"}),
    InsertOne({"course": "Global Studies 101", "enrollments": 22, "department": "International Relations"}),
    InsertOne({"course": "Astronomy 201", "enrollments": 18, "department": "Physics"}),
    InsertOne({"course": "Advanced Data Science", "enrollments": 50, "department": "Computer Science"}),
    InsertOne({"course": "Photography 101", "enrollments": 35, "department": "Arts"}),
    InsertOne({"course": "History 301", "enrollments": 30, "department": "History"}),
    InsertOne({"course": "Economics 202", "enrollments": 45, "department": "Economics"}),
    InsertOne({"course": "Advanced Sociology 302", "enrollments": 20, "department": "Sociology"}),
    InsertOne({"course": "Psychology 201", "enrollments": 28, "department": "Psychology"}),
    InsertOne({"course": "Neuroscience 101", "enrollments": 40, "department": "Neuroscience"}),
    InsertOne({"course": "Engineering 202", "enrollments": 50, "department": "Engineering"}),
    InsertOne({"course": "Literature 201", "enrollments": 60, "department": "English"}),
    InsertOne({"course": "French 101", "enrollments": 42, "department": "Languages"}),
    InsertOne({"course": "Spanish 101", "enrollments": 35, "department": "Languages"}),
    InsertOne({"course": "Chinese 102", "enrollments": 22, "department": "Languages"}),
    InsertOne({"course": "Math 102", "enrollments": 28, "department": "Mathematics"}),
    InsertOne({"course": "Cybersecurity 101", "enrollments": 45, "department": "Computer Science"}),
    InsertOne({"course": "International Relations 101", "enrollments": 15, "department": "Political Science"}),
    InsertOne({"course": "Fashion Design 101", "enrollments": 50, "department": "Design"}),
    InsertOne({"course": "Graphic Design 201", "enrollments": 40, "department": "Design"}),
    InsertOne({"course": "Nutrition 101", "enrollments": 32, "department": "Nutrition"}),
    InsertOne({"course": "Art 101", "enrollments": 30, "department": "Art"}),
    InsertOne({"course": "Dance 201", "enrollments": 20, "department": "Performing Arts"})
]

courses_collection.bulk_write(operations)
print("Courses inserted successfully.")
# Out:
# Courses inserted successfully.

# %%
# Displaying the data
for document in courses_collection.find():
    print(document)
# Out:
# {'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690def92ea78dfa4e8161719'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e816171a'), 'course': 'History 201', 'enrollments': 20, 'department': 'History'}
# {'_id': ObjectId('690def92ea78dfa4e816171b'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics'}
# {'_id': ObjectId('690def92ea78dfa4e816171c'), 'course': 'Chemistry 101', 'enrollments': 40, 'department': 'Chemistry'}
# {'_id': ObjectId('690def92ea78dfa4e816171d'), 'course': 'Biology 103', 'enrollments': 35, 'department': 'Biology'}
# {'_id': ObjectId('690def92ea78dfa4e816171e'), 'course': 'Art History 201', 'enrollments': 12, 'department': 'Art'}
# {'_id': ObjectId('690def92ea78dfa4e816171f'), 'course': 'Psychology 102', 'enrollments': 50, 'department': 'Psychology'}
# ...

# %% [markdown]
# ### 2. Complex Filtering and Querying
# - **Exercise 2**: Filter courses with enrollments over 20 students.
# - **Task 2**: Retrieve and display courses only from the "Computer Science" or "Mathematics" departments.

# %%
# Query for courses with enrollments greater than 20
for course in courses_collection.find({"enrollments": {"$gt": 20}}):
    print(course)
# Out:
# {'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690def92ea78dfa4e8161719'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e816171c'), 'course': 'Chemistry 101', 'enrollments': 40, 'department': 'Chemistry'}
# {'_id': ObjectId('690def92ea78dfa4e816171d'), 'course': 'Biology 103', 'enrollments': 35, 'department': 'Biology'}
# {'_id': ObjectId('690def92ea78dfa4e816171f'), 'course': 'Psychology 102', 'enrollments': 50, 'department': 'Psychology'}
# {'_id': ObjectId('690def92ea78dfa4e8161720'), 'course': 'Philosophy 202', 'enrollments': 22, 'department': 'Philosophy'}
# {'_id': ObjectId('690def92ea78dfa4e8161721'), 'course': 'Economics 101', 'enrollments': 60, 'department': 'Economics'}
# {'_id': ObjectId('690def92ea78dfa4e8161722'), 'course': 'Sociology 101', 'enrollments': 45, 'department': 'Sociology'}
# ...

# %%
# Query courses in Computer Science or Mathematics departments
for course in courses_collection.find({"department": {"$in": ["Computer Science", "Mathematics"]}}):
    print(course)
# Out:
# {'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690def92ea78dfa4e8161719'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e8161726'), 'course': 'Statistics 101', 'enrollments': 42, 'department': 'Mathematics'}
# {'_id': ObjectId('690def92ea78dfa4e8161727'), 'course': 'Computer Science 103', 'enrollments': 19, 'department': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e8161736'), 'course': 'Data Science 101', 'enrollments': 18, 'department': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e8161742'), 'course': 'Advanced Data Science', 'enrollments': 50, 'department': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e816174e'), 'course': 'Math 102', 'enrollments': 28, 'department': 'Mathematics'}
# ...

# %% [markdown]
# ### 3. Aggregation Framework for Data Analysis
# - **Exercise 3**: Use aggregation to find the average enrollment per department.
# - **Task 3**: Create an aggregation pipeline that finds the maximum enrollment for each department.

# %%
# Average enrollment per department using aggregation
pipeline = [
    {"$group": {"_id": "$department", "average_enrollment": {"$avg": "$enrollments"}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Economics', 'average_enrollment': 52.5}
# {'_id': 'Pharmacy', 'average_enrollment': 25.0}
# {'_id': 'Design', 'average_enrollment': 39.333333333333336}
# {'_id': 'Physics', 'average_enrollment': 18.333333333333332}
# {'_id': 'Art', 'average_enrollment': 21.0}
# {'_id': 'Chemistry', 'average_enrollment': 26.0}
# {'_id': 'English', 'average_enrollment': 57.5}
# {'_id': 'History', 'average_enrollment': 25.0}
# {'_id': 'Sociology', 'average_enrollment': 33.333333333333336}
# {'_id': 'Nutrition', 'average_enrollment': 32.0}
# {'_id': 'Performing Arts', 'average_enrollment': 21.666666666666668}
# {'_id': 'Psychology', 'average_enrollment': 39.0}
# {'_id': 'Mathematics', 'average_enrollment': 33.333333333333336}
# {'_id': 'Earth Sciences', 'average_enrollment': 16.0}
# {'_id': 'International Relations', 'average_enrollment': 22.0}
# {'_id': 'Languages', 'average_enrollment': 33.0}
# {'_id': 'Anthropology', 'average_enrollment': 38.0}
# ...

# %%
# Maximum enrollment per department
pipeline = [
    {"$group": {"_id": "$department", "max_enrollment": {"$max": "$enrollments"}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Economics', 'max_enrollment': 60}
# {'_id': 'Pharmacy', 'max_enrollment': 25}
# {'_id': 'Design', 'max_enrollment': 50}
# {'_id': 'Physics', 'max_enrollment': 22}
# {'_id': 'Art', 'max_enrollment': 30}
# {'_id': 'Chemistry', 'max_enrollment': 40}
# {'_id': 'English', 'max_enrollment': 60}
# {'_id': 'History', 'max_enrollment': 30}
# {'_id': 'Sociology', 'max_enrollment': 45}
# {'_id': 'Nutrition', 'max_enrollment': 32}
# {'_id': 'Performing Arts', 'max_enrollment': 30}
# {'_id': 'Psychology', 'max_enrollment': 50}
# {'_id': 'Mathematics', 'max_enrollment': 42}
# {'_id': 'Earth Sciences', 'max_enrollment': 16}
# {'_id': 'International Relations', 'max_enrollment': 22}
# {'_id': 'Languages', 'max_enrollment': 42}
# {'_id': 'Anthropology', 'max_enrollment': 38}
# {'_id': 'Philosophy', 'max_enrollment': 22}
# {'_id': 'Music', 'max_enrollment': 18}
# {'_id': 'Public Health', 'max_enrollment': 49}
# {'_id': 'Computer Science', 'max_enrollment': 50}
# ...

# %% [markdown]
# ### 4. Data Transformation using $project and $addFields
# - **Exercise 4**: Use `$project` to rename and only show fields: `course_name`, `department_name`, and `enrollments`.
# - **Task 4**: Use `$addFields` to create a new field `enrollment_category` where enrollments > 20 are "high" and others "low".

# %%
# Projection to rename fields
pipeline = [
    {"$project": {"course_name": "$course", "department_name": "$department", "enrollments": 1}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('690def92ea78dfa4e8161718'), 'enrollments': 30, 'course_name': 'Math 101', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690def92ea78dfa4e8161719'), 'enrollments': 25, 'course_name': 'CS 102', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690def92ea78dfa4e816171a'), 'enrollments': 20, 'course_name': 'History 201', 'department_name': 'History'}
# {'_id': ObjectId('690def92ea78dfa4e816171b'), 'enrollments': 15, 'course_name': 'Physics 202', 'department_name': 'Physics'}
# {'_id': ObjectId('690def92ea78dfa4e816171c'), 'enrollments': 40, 'course_name': 'Chemistry 101', 'department_name': 'Chemistry'}
# {'_id': ObjectId('690def92ea78dfa4e816171d'), 'enrollments': 35, 'course_name': 'Biology 103', 'department_name': 'Biology'}
# {'_id': ObjectId('690def92ea78dfa4e816171e'), 'enrollments': 12, 'course_name': 'Art History 201', 'department_name': 'Art'}
# ...

# %%
# Adding enrollment category field based on enrollments
pipeline = [
    {"$addFields": {"enrollment_category": {"$cond": {"if": {"$gt": ["$enrollments", 20]}, "then": "high", "else": "low"}}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690def92ea78dfa4e8161719'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690def92ea78dfa4e816171a'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('690def92ea78dfa4e816171b'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrollment_category': 'low'}
# {'_id': ObjectId('690def92ea78dfa4e816171c'), 'course': 'Chemistry 101', 'enrollments': 40, 'department': 'Chemistry', 'enrollment_category': 'high'}
# {'_id': ObjectId('690def92ea78dfa4e816171d'), 'course': 'Biology 103', 'enrollments': 35, 'department': 'Biology', 'enrollment_category': 'high'}
# ...

# %% [markdown]
# ### Homework for Students
# - **Homework 1**: Perform an aggregation to get a count of courses per department.
# - **Homework 2**: Use `$match` and `$group` together to filter and get only courses with enrollments over 25 in "Computer Science".
# - **Homework 3**: Apply `$lookup` to join `courses` collection with `students` collection based on student enrollments.

# %%
# Perform an aggregation to get a count of courses per department.
pipeline = [
    {"$group": {"_id": "$department", "count": {"$sum": 1}}}
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Chemistry', 'count': 2}
# {'_id': 'Biochemistry', 'count': 1}
# {'_id': 'Arts', 'count': 1}
# {'_id': 'Urban Studies', 'count': 1}
# {'_id': 'Law', 'count': 1}
# {'_id': 'Business', 'count': 3}
# {'_id': 'Political Science', 'count': 2}
# {'_id': 'Biology', 'count': 1}
# {'_id': 'Neuroscience', 'count': 1}
# {'_id': 'Linguistics', 'count': 1}
# {'_id': 'Music', 'count': 1}
# {'_id': 'Philosophy', 'count': 1}
# {'_id': 'Anthropology', 'count': 1}
# {'_id': 'Earth Sciences', 'count': 1}
# {'_id': 'Mathematics', 'count': 3}
# {'_id': 'Medicine', 'count': 1}
# {'_id': 'Environmental Studies', 'count': 1}
# {'_id': 'Engineering', 'count': 4}
# {'_id': 'Accounting', 'count': 1}
# {'_id': 'International Relations', 'count': 1}
# {'_id': 'Computer Science', 'count': 5}
# {'_id': 'Public Health', 'count': 1}
# {'_id': 'Design', 'count': 3}
# {'_id': 'Pharmacy', 'count': 1}
# {'_id': 'Physics', 'count': 3}
# {'_id': 'Art', 'count': 2}
# {'_id': 'Economics', 'count': 2}
# ...

# %%
# Use `$match` and `$group` together to filter and get only courses with enrollments over 25 in "Computer Science".

pipeline = [
    {
        "$match": {
            "department": "Computer Science",
            "enrollments": {"$gt": 25}
        }
    },
    {
        "$group": {
            "_id": "$department",
            "courses": {"$push": "$course"}
        }
    }
]

for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Computer Science', 'courses': ['Advanced Data Science', 'Cybersecurity 101']}

# %%
# Apply `$lookup` to join `courses` collection with `students` collection based on student enrollments.

students_collection = db["students"]

# Start with an empty collection
students_collection.delete_many({})

students_collection.insert_many([
    { "name": "Alice Johnson", "course": "Math 101", "department": "Mathematics" },
    { "name": "Liam Stevens", "course": "Math 101", "department": "Mathematics" },
    { "name": "Sophia Mitchell", "course": "Math 101", "department": "Mathematics" },
    { "name": "James Clark", "course": "Math 101", "department": "Mathematics" },
    { "name": "Olivia Walker", "course": "Math 101", "department": "Mathematics" },
    { "name": "Noah Lewis", "course": "Math 101", "department": "Mathematics" },
    { "name": "Emma Harris", "course": "Math 101", "department": "Mathematics" },
    { "name": "Benjamin Robinson", "course": "Math 101", "department": "Mathematics" },
    { "name": "Ava Evans", "course": "Math 102", "department": "Mathematics" },
    { "name": "Lucas Hall", "course": "Math 102", "department": "Mathematics" },
    { "name": "Ethan Turner", "course": "Math 102", "department": "Mathematics" },
    { "name": "Isabella Martinez", "course": "Math 102", "department": "Mathematics" },
    { "name": "Mason Lee", "course": "Statistics 101", "department": "Mathematics" },
    { "name": "Charlotte White", "course": "Statistics 101", "department": "Mathematics" },
    { "name": "Daniel King", "course": "Statistics 101", "department": "Mathematics" },
    { "name": "Amelia Scott", "course": "Statistics 101", "department": "Mathematics" },
    { "name": "Jack Harper", "course": "CS 102", "department": "Computer Science" },
    { "name": "Zoe Adams", "course": "CS 102", "department": "Computer Science" },
    { "name": "Mia Foster", "course": "CS 102", "department": "Computer Science" },
    { "name": "Henry Carter", "course": "CS 102", "department": "Computer Science" },
    { "name": "Alexander Wright", "course": "CS 102", "department": "Computer Science" },
    { "name": "Victoria Lewis", "course": "CS 102", "department": "Computer Science" },
    { "name": "Leo Rodriguez", "course": "Computer Science 103", "department": "Computer Science" },
    { "name": "Charlotte Miller", "course": "Computer Science 103", "department": "Computer Science" },
    { "name": "Samuel Baker", "course": "Computer Science 103", "department": "Computer Science" },
    { "name": "Amos Brooks", "course": "Advanced Data Science", "department": "Computer Science" },
    { "name": "Lily Reed", "course": "Advanced Data Science", "department": "Computer Science" },
    { "name": "Max Jenkins", "course": "Advanced Data Science", "department": "Computer Science" },
    { "name": "Nina Carter", "course": "History 201", "department": "History" },
    { "name": "Oliver Scott", "course": "History 201", "department": "History" },
    { "name": "Lucas Harris", "course": "History 201", "department": "History" },
    { "name": "Grace Miller", "course": "History 301", "department": "History" },
    { "name": "Isaac Bailey", "course": "History 301", "department": "History" },
    { "name": "Ella Thompson", "course": "Psychology 102", "department": "Psychology" },
    { "name": "Sophia Walker", "course": "Psychology 102", "department": "Psychology" },
    { "name": "John Davis", "course": "Psychology 102", "department": "Psychology" },
    { "name": "Dylan Thomas", "course": "Psychology 201", "department": "Psychology" },
    { "name": "Lily Evans", "course": "Psychology 201", "department": "Psychology" },
    { "name": "Robert Miller", "course": "Chemistry 101", "department": "Chemistry" },
    { "name": "Sophia White", "course": "Chemistry 101", "department": "Chemistry" },
    { "name": "Liam Anderson", "course": "Chemistry 101", "department": "Chemistry" },
    { "name": "Avery Green", "course": "Advanced Chemistry 301", "department": "Chemistry" },
    { "name": "David Johnson", "course": "Engineering 101", "department": "Engineering" },
    { "name": "Emily Clark", "course": "Engineering 101", "department": "Engineering" },
    { "name": "Michael King", "course": "Engineering 101", "department": "Engineering" },
    { "name": "Jack Brown", "course": "Engineering 202", "department": "Engineering" },
    { "name": "Olivia Taylor", "course": "Engineering 202", "department": "Engineering" },
    { "name": "Amelia Stone", "course": "Art History 201", "department": "Art" },
    { "name": "Oliver Carter", "course": "Art History 201", "department": "Art" },
    { "name": "Lucas Lee", "course": "Art 101", "department": "Art" }
])

pipeline = [
    {
        "$lookup": {
            "from": "courses",
            "localField": "course",
            "foreignField": "course",
            "as": "matching_course"
        }
    },
]

for result in students_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('690def95ea78dfa4e8161756'), 'name': 'Alice Johnson', 'course': 'Math 101', 'department': 'Mathematics', 'matching_course': [{'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}]}
# {'_id': ObjectId('690def95ea78dfa4e8161757'), 'name': 'Liam Stevens', 'course': 'Math 101', 'department': 'Mathematics', 'matching_course': [{'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}]}
# {'_id': ObjectId('690def95ea78dfa4e8161758'), 'name': 'Sophia Mitchell', 'course': 'Math 101', 'department': 'Mathematics', 'matching_course': [{'_id': ObjectId('690def92ea78dfa4e8161718'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}]}
# ...
